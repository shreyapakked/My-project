# %%
import random

games_played=0
games_won=0
games_lost=0
high_score=0
play_again="yes"

while play_again=="yes":
    games_played=games_played+1
    
    print("choose difficulty")
    print("1.Easy")
    print("1.medium")
    print("3.difficulty")

    try:
        guess=int(input("enter your guess:", ))
    except ValueError:
        print("please enter valid number")
        ch=1
     
     if ch==1:
        maximum=50
        attempts=10
     elif ch==2:
        maximum=300
        attempte=7
     elif ch==3:
        maximum=500
        attempte=5
     else:
        print("invalid choice")
         
     a=random.randint(1,maximum)    
     score=100

     while attempts>0:
         try:
            guess = int(input("Enter your guess: "))
         except ValueError:
             print("Please enter valid number.")
             continue
    
         if guess < 1 or guess > maximum:
             print("please enter a number between 1 and maximum")
             continue
         if guess>a:
             print("too high")
         elif guess<a:
             print("too low")
         else:
             print("you are correct🎉")
             print("your score:",score)

             games_won=games_won+1

             if score>high_score:
                 high_score=score
             break
         attempts=attempts-1
         score=score-10  
         print("number of attempts left is:",attempts)
     else:
         print("\ngame over😔")
         print("correct number is:",a)

         games_lost=games_lost+1
     play_again=input("dou you want to play again(yes/no):",).lower()
print("\n=========GAME STATISTIC===========")
print("Games played:",games_played)
print("Games won:",games_won)
print("Games lost:",games_lost)
print("high scored:",high_score)

print("thanks for playing🎮🎮")
# Out:
#   File <string>:19
#     except ValueError:
#                       ^
# IndentationError: unindent does not match any outer indentation level
